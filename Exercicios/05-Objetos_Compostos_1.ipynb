# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# A utilização de objetos compostos garante agrupar várias informações complexas de maneira lógica, garantindo uma maior eficiência e estruturação dos dados.

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
c_tupla = ("coxinha", 
           "coberta", 
           "caramelo",
           "casquinha", 
           "cascalho")
c_tupla
# Out:
# ('coxinha', 'coberta', 'caramelo', 'casquinha', 'cascalho')

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
numero_lista = [1.2, 2, 3.3, 4, 5]
numero_lista
# Out:
# [1.2, 2, 3.3, 4, 5]

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
genes_lista = ["gapdh", "icam", "mcp1", "tgfb", "sdc1"]

print(genes_lista[0])
print(genes_lista[1])
print(genes_lista[2])
print(genes_lista[3])
print(genes_lista[4])
# Out:
# gapdh
# icam
# mcp1
# tgfb
# sdc1

# %%
print(genes_lista[0].count('a'))
print(genes_lista[1].count('a'))
print(genes_lista[2].count('a'))
print(genes_lista[3].count('a'))
print(genes_lista[4].count('a'))
# Out:
# 1
# 1
# 0
# 0
# 0

# %%
for gene in genes_lista:
      print(gene.count("a"))
# Out:
# 1
# 1
# 0
# 0
# 0

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
lista = [11, 22, 33, 44, 55]
lista[1:4]
# Out:
# [22, 33, 44]

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome_str = "Julia"
segundo = nome_str[1]
ultimo = nome_str[-1]
print(segundo)
print(ultimo)
# Out:
# u
# a

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
infos_Dicionario = {"a": 1, 
                    "b": 9, 
                    "c": 21, 
                    "d": 48}
type(infos_Dicionario)
# Out:
# dict

# %%
print(len(infos_Dicionario))
# Out:
# 4

# %%
print(sum(infos_Dicionario.values()))
# Out:
# 79

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
genes_lista
# Out:
# ['gapdh', 'icam', 'mcp1', 'tgfb', 'sdc1']

# %%
dicionario = {
    genes_lista[0]: len(genes_lista[0]),
    genes_lista[1]: len(genes_lista[1]),
    genes_lista[2]: len(genes_lista[2]),
    genes_lista[3]: len(genes_lista[3]),
    genes_lista[4]: len(genes_lista[4])
}
dicionario
# Out:
# {'gapdh': 5, 'icam': 4, 'mcp1': 4, 'tgfb': 4, 'sdc1': 4}

# %%
genes_lista 
dicionario = {}

for index in range(len(genes_lista)):
    gene = genes_lista[index]
    dicionario[gene] = len(gene)

print(dicionario)
# Out:
# {'gapdh': 5, 'icam': 4, 'mcp1': 4, 'tgfb': 4, 'sdc1': 4}

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
genes_lista
# Out:
# ['gapdh', 'icam', 'mcp1', 'tgfb', 'sdc1']

# %%
i = 0
gapdh = [
    len(genes_lista[i]),
    genes_lista[i][:2],
    genes_lista[i].count("a"),
    "hu" in genes_lista[i]
]
print(gapdh)
# Out:
# [5, 'ga', 1, False]

# %%
i = 1
icam = [
    len(genes_lista[i]),
    genes_lista[i][:2],
    genes_lista[i].count("a"),
    "hu" in genes_lista[i]
]
print(icam)
# Out:
# [4, 'ic', 1, False]

# %%
i = 2
mcp1 = [
    len(genes_lista[i]),
    genes_lista[i][:2],
    genes_lista[i].count("a"),
    "hu" in genes_lista[i]
]
print(mcp1)
# Out:
# [4, 'mc', 0, False]

# %%
i = 3
tgfb = [
    len(genes_lista[i]),
    genes_lista[i][:2],
    genes_lista[i].count("a"),
    "hu" in genes_lista[i]
]
print(tgfb)
# Out:
# [4, 'tg', 0, False]

# %%
i = 4
sdc1 = [
    len(genes_lista[i]),
    genes_lista[i][:2],
    genes_lista[i].count("a"),
    "hu" in genes_lista[i]
]
print(sdc1)
# Out:
# [4, 'sd', 0, False]

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
genes_lista
# Out:
# ['gapdh', 'icam', 'mcp1', 'tgfb', 'sdc1']

# %%
print(genes_lista[0])
print(genes_lista[1])
print(genes_lista[2])
print(genes_lista[3])
print(genes_lista[4])
# Out:
# gapdh
# icam
# mcp1
# tgfb
# sdc1

# %%
dicionario = {
    genes_lista[0]: gapdh,
    genes_lista[1]: icam,
    genes_lista[2]: mcp1,
    genes_lista[3]: tgfb,
    genes_lista[4]: sdc1
}
dicionario
# Out:
# {'gapdh': [5, 'ga', 1, False],
#  'icam': [4, 'ic', 1, False],
#  'mcp1': [4, 'mc', 0, False],
#  'tgfb': [4, 'tg', 0, False],
#  'sdc1': [4, 'sd', 0, False]}
