# %% [markdown]
# # Explicação Rotina
#
# https://1drv.ms/v/c/808ebfd9a0d86213/IQA1p5nBtUMiS4C1k70ZRFf3ASpmGVhaRHc_ibt9GJbkfww?e=9Er6z5

# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: Vantagens: a usabilidade pois consegue reutilizar o código; a organização - uma função que faz somente uma tarefa; a da correção - basta corrigir uma vez; e o ganho em processamento porque não executa tudo na mesma hora e ao mesmo tempo.
#
# R2: Características: possui parâmetros - receber dados para processar; retorna valor - após o processamento a função pode devolver um resultado

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R1 = Definir um objeto1() - função - que retorne um np com valores randomicos e normais com média 10, desvio padrão 3 de 5 valores.
#
# R2 = definir os valores maiores que 10 em um array "NOME" com inteiros que recebem 10. Instanciar quais que recebem o array, com os números maiores que os definidos no array "NOME". Instanciar quantos que recebe a função contar a quantidade de elementos dentro do objeto quais. Retornar quais e quantos
#
# R3 = Intanciar um objeto que recebe o objeto1() - função. Intanciar quais e quantos que recebem valores_maiores_que_10 no objeto instanciado previamente. Imprimir a mensagem "Array gerado" para os elementos contidos em objeto, "quais valores >10" para saber quais valores são maiores que 10 e "quantidade de valores >10" para contar o n° de valores maiores que 10

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/Fluxograma8.jpg" width="500" />

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
## Exercício 2 aula 10

import numpy as np
obj_12 = np.random.normal(10, 3, 5)
print(obj_12)
# Out:
# [10.27445236  5.96774965  6.11200716 13.41262321  8.60234095]

# %%
## Exercício 2 aula 10

maiores_10 = obj_12 > 10
print(maiores_10)

quais_10 = obj_12[obj_12 > 10]
print(quais_10)
# Out:
# [ True False False  True False]
# [10.27445236 13.41262321]

# %%
## Incluindo função
def gerar_obj12():
    return np.random.normal(10, 3, 5)

# %%
def valores_maiores_que_10(array, patinho_amarelo: int = 10):
    quais = array[array > patinho_amarelo]
    quantos = len(quais)
    return quais, quantos

# %%
obj = gerar_obj12()
quais, quantos = valores_maiores_que_10(obj)

print("Array gerado:", obj)
print("Quais valores > 10:", quais)
print("Quantidade de valores > 10:", quantos)
# Out:
# Array gerado: [ 9.95426714  4.2899866   8.21947247 10.06257825  8.6178622 ]
# Quais valores > 10: [10.06257825]
# Quantidade de valores > 10: 1

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# Sim, o racional utiliza a indexação booleana que permite filtrar os valores em qualquer condição desde que alterada a condição da comparação, nesse caso superior a 10 e superior a 20

# %%
obj = gerar_obj12()
quais, quantos = valores_maiores_que_10(obj, patinho_amarelo = 20)

print("Array gerado:", obj)
print("Quais valores > 20:", quais)
print("Quantidade de valores > 20:", quantos)
# Out:
# Array gerado: [ 8.02637678 15.26248126 10.87189959 10.6899726   6.14917902]
# Quais valores > 20: []
# Quantidade de valores > 20: 0

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R1 = Defina media em um conjunto de valores, na qual o n de valores recebe valores quaisquer
#
# R2 = Define a media de valores, na qual a soma recebe o comando sum contido dentro de valores; quantidade recebe o comando len para a quantidade de valores dentro do conjunto valores; media1 recebe soma/quantidade, retornar a media1. O resultado recebe o retorno da função media condita nesses valores quaisquer
#
# R3 = imprimir resultado como média

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/Fluxograma10.jpg" width="500" />

# %% [markdown]
# ## 08 – Escreva o programa em Python:

# %%
n_valores = [10, 24, 33, 45, 2]

def media(valores):
    soma = sum(valores)
    quantidade = len(valores)
    media1 = soma / quantidade
    return media1

resultado = media(n_valores)
print("Média:", resultado)
# Out:
# Média: 22.8

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
obj1 = 10
obj2 = 5

def dividir(obj1, obj2):
    if type(obj1) == int and type(obj2) == int:
            return obj1/obj2
    else:
            return "Valores não são inteiros"

print("obj1:", type(obj1), "valor:", obj1)
print("obj2:", type(obj2), "valor:", obj2)
print("resultado:", dividir(obj1, obj2))
# Out:
# obj1: <class 'int'> valor: 10
# obj2: <class 'int'> valor: 5
# resultado: 2.0

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
obj1 = (1, 2, 10)
obj2 = (25, 42, 2)

def dividir_composto(obj1, obj2):
    resultado = []
    if type(obj1) == tuple and type(obj2) == tuple:
        for n in range (len(obj1)):   
              resultado.append(dividir(obj1[n], obj2[n]))
        return resultado
    else:
        return "Valores não são inteiros"

print("obj1:", type(obj1), "valor:", obj1)
print("obj2:", type(obj2), "valor:", obj2)
print("resultado:", dividir_composto(obj1, obj2))
# Out:
# obj1: <class 'tuple'> valor: (1, 2, 10)
# obj2: <class 'tuple'> valor: (25, 42, 2)
# resultado: [0.04, 0.047619047619047616, 5.0]
