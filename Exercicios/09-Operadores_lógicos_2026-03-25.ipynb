# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Dados as operações abaixo, qual o resultado da operação lógica:
#
# <br>
# <br>Como os operadores lógicos podem ser usados para inverter o resultado?
#
# p and q and r and s and t
#
# <br>p = 2.0 + 3.0 / 5.0 == 10
# <br>q = (p + 10.2) - 5.0 * 2.0 <= 2.9
# <br>r = 10 <= p / q + 33.8 < 100
# <br>s = 5 != p / (q + r)
# <br>t = 33 == s * 2

# %%
resultado_p = 2.0 + 3.0 / 5.0 == 10
resultado_p
# Out:
# False

# %%
resultado_q = (resultado_p + 10.2) - 5.0 * 2.0 <= 2.9
resultado_q
# Out:
# True

# %%
resultado_r = 10 <= resultado_p / resultado_q + 33.8 < 100
resultado_r
# Out:
# True

# %%
resultado_s = 5 != resultado_p / (resultado_q + resultado_r)
resultado_s
# Out:
# True

# %%
resultado_t = 33 == resultado_s * 2
resultado_t
# Out:
# False

# %%
valor = resultado_p and resultado_q and resultado_r and resultado_s and resultado_t
valor
# Out:
# False

# %%
valor2 = not (resultado_p and resultado_q and resultado_r and resultado_s and resultado_t)
valor2
# Out:
# True

# %% [markdown]
# ## 02 – Usando apenas o operador or, qual seria o resultado final das operações abaixo? Como deve ser usado o not para inverter o resultado?
#
# <br>p = ('a',1,True,'b',0,False) != ('a',True,1,'b',False,0)
# <br>q = ['a',1,True,'b',0,False] != ('a',True,1,'b',False,0)
# <br>r = ['a',1,True,'b',0,False] != ['a',True,1,'b',False,0]
# <br>s = ['a',1,True,'b',0,False] > ['a',True,1]
# <br>t = ['a',1,True,'b',0,False] == 1
# <br>u = ['a',True,1] <= ['a',True,1] < ['a',1,True,'b',0,False]

# %%
p = ('a',1,True,'b',0,False) != ('a',True,1,'b',False,0)
p
# Out:
# False

# %%
q = ['a',1,True,'b',0,False] != ('a',True,1,'b',False,0)
q
# Out:
# True

# %%
r = ['a',1,True,'b',0,False] != ['a',True,1,'b',False,0]
r
# Out:
# False

# %%
s = ['a',1,True,'b',0,False] > ['a',True,1]
s
# Out:
# True

# %%
t = ['a',1,True,'b',0,False] == 1
t
# Out:
# False

# %%
u = ['a',True,1] <= ['a',True,1] < ['a',1,True,'b',0,False]
u
# Out:
# True

# %%
valor3 = p or q or r or s or t or u
valor3
# Out:
# True

# %%
valor4 = not (p or q or r or s or t or u)
valor4
# Out:
# False

# %% [markdown]
# ## 03 – No exercício 3 da aula 8 foi importado um arquivo .csv para um objeto da classe DataFrame pandas. Importe aqui o mesmo objeto e arredonde e edite o index como realizado no exercício 3 da aula 8. Usando operadores responda, a segunda linha é igual a terceira ou a terceira linha é igual a quarta?

# %%
import pandas as pd

# %%
df_novo7 = pd.read_csv("arquivoaula7.csv", index_col="Unnamed: 0")
df_novo7 = df_novo7.round(3)
df_novo7
# Out:
#                     a      b       c      d  media_linhas
# amarelo         2.600  2.800  34.729  0.069        10.050
# azul            0.139  1.612   1.673  5.893         2.329
# vermelho        0.263  0.372   2.600  2.800         1.509
# roxo           34.729  0.069   0.139  1.612         9.137
# verde           1.673  5.893   0.263  0.372         2.050
# media_colunas   7.881  2.149   7.881  2.149         5.015

# %%
linha2 = df_novo7.iloc[1]
linha3 = df_novo7.iloc[2]
linha4 = df_novo7.iloc[3]

resultado = (linha2 == linha3).all() or (linha3 == linha4).all()
print(resultado)
# Out:
# False

# %% [markdown]
# ## 04 – Usando operadores verifique se todos os valores contidos na primeira linha são maiores ou iguais a 10.

# %%
linha1 = df_novo7.iloc[0]
maior_ou_igual = (linha1 >= 10).all()
print(maior_ou_igual)
# Out:
# False

# %%
print(linha1)
# Out:
# a                2.600
# b                2.800
# c               34.729
# d                0.069
# media_linhas    10.050
# Name: amarelo, dtype: float64

# %% [markdown]
# ## 05 – Usando operadores verifique se todos os valores contidos na terceira coluna estão entre 0 inclusive e 40.

# %%
##Todos = .all()
coluna3 = df_novo7.iloc[:, 2]
resultado = ((coluna3 >= 0) & (coluna3 <= 40)).all()
print(resultado)
# Out:
# True

# %%
print(coluna3)
# Out:
# amarelo          34.729
# azul              1.673
# vermelho          2.600
# roxo              0.139
# verde             0.263
# media_colunas     7.881
# Name: c, dtype: float64

# %% [markdown]
# ## 06 – Usando operadores verifique se algum dos valores contidos na última linha está acima de 10.

# %%
## Algum: .any()
ultima_linha = df_novo7.iloc[-1]
acima_10 = (ultima_linha > 10).any()
print(acima_10)
# Out:
# False

# %%
print(ultima_linha)
# Out:
# a               7.881
# b               2.149
# c               7.881
# d               2.149
# media_linhas    5.015
# Name: media_colunas, dtype: float64

# %% [markdown]
# ## 07 – Recupere a DataFrame contendo apenas valores que estejam acima de 5 e abaixo de 7.

# %%
### and = &
acima5 = df_novo7[(df_novo7 > 5) & (df_novo7 < 7)]
print(acima5)
# Out:
#                 a      b   c      d  media_linhas
# amarelo       NaN    NaN NaN    NaN           NaN
# azul          NaN    NaN NaN  5.893           NaN
# vermelho      NaN    NaN NaN    NaN           NaN
# roxo          NaN    NaN NaN    NaN           NaN
# verde         NaN  5.893 NaN    NaN           NaN
# media_colunas NaN    NaN NaN    NaN         5.015

# %%
print(df_novo7)
# Out:
#                     a      b       c      d  media_linhas
# amarelo         2.600  2.800  34.729  0.069        10.050
# azul            0.139  1.612   1.673  5.893         2.329
# vermelho        0.263  0.372   2.600  2.800         1.509
# roxo           34.729  0.069   0.139  1.612         9.137
# verde           1.673  5.893   0.263  0.372         2.050
# media_colunas   7.881  2.149   7.881  2.149         5.015

# %% [markdown]
# ## 08 – Recupere a DataFrame contendo apenas valores que estejam abaixo de 5 inclusive ou acima de 7.

# %%
# or = |
abaixo5 = df_novo7[(df_novo7 <= 5) | (df_novo7 > 7)]
print(abaixo5)
# Out:
#                     a      b       c      d  media_linhas
# amarelo         2.600  2.800  34.729  0.069        10.050
# azul            0.139  1.612   1.673    NaN         2.329
# vermelho        0.263  0.372   2.600  2.800         1.509
# roxo           34.729  0.069   0.139  1.612         9.137
# verde           1.673    NaN   0.263  0.372         2.050
# media_colunas   7.881  2.149   7.881  2.149           NaN

# %% [markdown]
# ## 09 – Converta as duas últimas colunas do objeto DataFrame para dois objetos da classe numpy array. Algum dos valores contidos no primeiro array estão entre 2 inclusive e 5 inclusive?

# %%
##Convertendo Df em array
array1 = df_novo7.iloc[:, -2].to_numpy()
array2 = df_novo7.iloc[:, -1].to_numpy()
print(array1)
print(array2)
# Out:
# [0.069 5.893 2.8   1.612 0.372 2.149]
# [10.05   2.329  1.509  9.137  2.05   5.015]

# %%
#Primeiro array
entre2_5_a1 = ((array1 >= 2) & (array1 <= 5)).any()
print(entre2_5_a1)
# Out:
# True

# %%
##Segundo array
entre2_5_a2 = ((array2 >= 2) & (array2 <= 5)).any()
print(entre2_5_a2)
# Out:
# True

# %%
## Juntando as duas ultimas colunas
array3 = [array1] + [array2]
array3
# Out:
# [array([0.069, 5.893, 2.8  , 1.612, 0.372, 2.149]),
#  array([10.05 ,  2.329,  1.509,  9.137,  2.05 ,  5.015])]

# %%
## Descobrindo quais são os valores contidos >=2 & <=5
import numpy as np
array3 = np.array(array3)
resultado = array3[(array3 >= 2) & (array3 <= 5)]
print(resultado)
# Out:
# [2.8   2.149 2.329 2.05 ]

# %% [markdown]
# ## 10 – Os valores contidos nos dois arrays são superiores à -1 e inferiores à 12?

# %%
supe_1_inf12 = ((array1 > -1) & (array1 < 12)).all() and ((array2 > -1) & (array2 < 12)).all()
print(supe_1_inf12)
# Out:
# True

# %%
## Mostrando quais são os valores maiores que -1 e menores que 12
resultado = array3[(array3 > -1) & (array3 <12)]
print(resultado)
# Out:
# [ 0.069  5.893  2.8    1.612  0.372  2.149 10.05   2.329  1.509  9.137
#   2.05   5.015]
