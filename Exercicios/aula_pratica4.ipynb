# %%
simbolo = [
    'IFNG',
    'Il10',
    'Ifn',
    'CSF2'
]
full_name = [
    'interferon gama',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating fator 2'
]
source = [
    'HGNC:HGNC:5438',
    'RDG:2886',
    'MGI:MGI:104798',
    'HGNC:HGNC:2434'
]
gene_type = [
    'protein conding',
    'protein conding',
    'protein conding',
    'protein conding'
]
organism = [
    'Homo sapiens',
    'Rattus norvegicus',
    'Mus musculus',
    'Homo sapiens',
]
chromosome = [
    12,
    13,
    17,
    5
]

# %%
gene_matriz_lista = [
    simbolo,
    full_name,
    source,
    gene_type,
    organism,
    chromosome
]
gene_matriz_lista
# Out:
# [['IFNG', 'Il10', 'Ifn', 'CSF2'],
#  ['interferon gama',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating fator 2'],
#  ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  ['protein conding', 'protein conding', 'protein conding', 'protein conding'],
#  ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus', 'Homo sapiens'],
#  [12, 13, 17, 5]]

# %% [markdown]
# ##
# Instanciar um dicionário
# CHaves serão os nomes de lista em strig
# Os valores serão as listas

# %%
dicionario = {
    "simbolo": simbolo,
    "full_name": full_name,
    "source": source,
    "gene_type": gene_type,
    "organism": organism,
    "chromosome": chromosome
    
}
dicionario
# Out:
# {'simbolo': ['IFNG', 'Il10', 'Ifn', 'CSF2'],
#  'full_name': ['interferon gama',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating fator 2'],
#  'source': ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein conding',
#   'protein conding',
#   'protein conding',
#   'protein conding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
import numpy as np

# %%
import pandas as pb

# %%
dicionario['simbolo']
# Out:
# ['IFNG', 'Il10', 'Ifn', 'CSF2']

# %%
simbolo.append('actina')
simbolo
# Out:
# ['IFNG', 'Il10', 'Ifn', 'CSF2', 'actina']

# %%
dicionario
# Out:
# {'simbolo': ['IFNG', 'Il10', 'Ifn', 'CSF2', 'actina'],
#  'full_name': ['interferon gama',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating fator 2'],
#  'source': ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein conding',
#   'protein conding',
#   'protein conding',
#   'protein conding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
dicionario['simbolo'].append('vir')

# %%
dicionario
# Out:
# {'simbolo': ['IFNG', 'Il10', 'Ifn', 'CSF2', 'actina', 'vir'],
#  'full_name': ['interferon gama',
#   'interleukin 10',
#   'tumor necrosis factor',
#   'colony stimulating fator 2'],
#  'source': ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#  'gene_type': ['protein conding',
#   'protein conding',
#   'protein conding',
#   'protein conding'],
#  'organism': ['Homo sapiens',
#   'Rattus norvegicus',
#   'Mus musculus',
#   'Homo sapiens'],
#  'chromosome': [12, 13, 17, 5]}

# %%
simbolo
# Out:
# ['IFNG', 'Il10', 'Ifn', 'CSF2', 'actina', 'vir']

# %%
simbolo.pop()
simbolo.pop()
# Out:
# 'actina'

# %%
simbolo
# Out:
# ['IFNG', 'Il10', 'Ifn', 'CSF2']

# %%
np.array(gene_matriz_lista)
# Out:
# array([['IFNG', 'Il10', 'Ifn', 'CSF2'],
#        ['interferon gama', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating fator 2'],
#        ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein conding', 'protein conding', 'protein conding',
#         'protein conding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U26')

# %%
gene_array = np.array(gene_matriz_lista)
gene_array
# Out:
# array([['IFNG', 'Il10', 'Ifn', 'CSF2'],
#        ['interferon gama', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating fator 2'],
#        ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434'],
#        ['protein conding', 'protein conding', 'protein conding',
#         'protein conding'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens'],
#        ['12', '13', '17', '5']], dtype='<U26')

# %%
gene_array.shape
# Out:
# (6, 4)

# %%
gene_array[[0,2]]
# Out:
# array([['IFNG', 'Il10', 'Ifn', 'CSF2'],
#        ['HGNC:HGNC:5438', 'RDG:2886', 'MGI:MGI:104798', 'HGNC:HGNC:2434']],
#       dtype='<U26')

# %%
index = [3, 1, 4]
gene_array [index]
# Out:
# array([['protein conding', 'protein conding', 'protein conding',
#         'protein conding'],
#        ['interferon gama', 'interleukin 10', 'tumor necrosis factor',
#         'colony stimulating fator 2'],
#        ['Homo sapiens', 'Rattus norvegicus', 'Mus musculus',
#         'Homo sapiens']], dtype='<U26')

# %%
gene_array[:,0]
# Out:
# array(['IFNG', 'interferon gama', 'HGNC:HGNC:5438', 'protein conding',
#        'Homo sapiens', '12'], dtype='<U26')

# %%
gene_array[:,[1,0]]
# Out:
# array([['Il10', 'IFNG'],
#        ['interleukin 10', 'interferon gama'],
#        ['RDG:2886', 'HGNC:HGNC:5438'],
#        ['protein conding', 'protein conding'],
#        ['Rattus norvegicus', 'Homo sapiens'],
#        ['13', '12']], dtype='<U26')

# %%
gene_array[-1,1:3]
# Out:
# array(['13', '17'], dtype='<U26')

# %% [markdown]
# #primeiro linha e depois coluna
# ##uma lista de coluna [-1, [1,0]]
# ###: é todas as linhas ou colunas
