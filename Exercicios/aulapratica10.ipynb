# %%
import pandas as pb
import numpy as np

# %%
array = np.random.normal(20, 2.5, 40)
array
# Out:
# array([24.33705718, 18.9808145 , 17.13752556, 21.6042036 , 18.83470298,
#        20.81970763, 19.99606515, 18.50225677, 25.07304608, 18.71958456,
#        21.65224269, 20.44923353, 19.48776365, 16.24354348, 25.80811557,
#        23.5417876 , 19.63032745, 19.64625171, 17.22435279, 21.7783804 ,
#        16.61697166, 16.50456336, 18.81605692, 19.05649907, 16.80990404,
#        19.35024289, 23.06063548, 22.78801954, 18.83540771, 18.53326301,
#        26.44243706, 16.47916107, 23.54677549, 17.45897335, 18.61203899,
#        14.176363  , 17.25314473, 23.04015168, 23.08429515, 20.69270264])

# %%
array = np.random.normal(20, 2.5, 40).reshape(8, 5)
array
# Out:
# array([[22.00528503, 14.52169668, 20.283434  , 24.89456246, 22.10428931],
#        [22.66496632, 20.94906828, 22.28066443, 17.61247274, 22.16463085],
#        [20.65628876, 22.07690009, 17.76073676, 19.41456728, 18.20238865],
#        [20.79145651, 15.59498176, 18.09055946, 19.23433438, 17.28377789],
#        [20.96443395, 21.43594282, 22.82965129, 18.30949913, 21.38132664],
#        [20.7511996 , 21.87813871, 18.55314608, 17.1587837 , 20.50082693],
#        [17.79821351, 18.73183625, 23.79955171, 22.09851366, 19.55660701],
#        [19.7698462 , 20.76817164, 17.67282879, 19.42963387, 19.93701705]])

# %%
array[3,1] >= 200
# Out:
# np.False_

# %%
if array[3,1] >= 200:
    pass
else: 
    pass

# %%
##elif coloca as condições que quer avaliar
if array[3,1] >= 200:
    resposta = "O valor é maior ou igual a 200"
elif array[3,1] <20:
    resposta = "O valor é menor que 20"
else: 
    resposta = "O valor não é maior ou igual a 200"
resposta
# Out:
# 'O valor é menor que 20'

# %%
np.all(array > 0)
# Out:
# np.True_

# %%
if np.all(array > 0):
    print("Todos os valores são maiores que 0")
# Out:
# Todos os valores são maiores que 0
