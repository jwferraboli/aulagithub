# %%
def fazer():
    pass

# %%
import pandas as pd

# %%
def contar_inteiros(obj: list | tuple, a, b, c) -> int:
    contador = 0
    for x in range(len(obj)):
        if type(obj[x]) == int:
            contador += 1
    print(f"Quantidade de inteiros: {contador}")
    return contador

# %%
resultado_contador = contar_inteiros([5], 1, 2, 3)
print(resultado_contador)
# Out:
# Quantidade de inteiros: 1
# 1

# %%
def contar_inteiros(obj: list | tuple) -> int:
    contador = sum(isinstance(elemento, int) for elemento in obj)
    print(f"Quantidade de inteiros: {contador}")
    return contador

obj = [1, 2, 3, 'a', 'b', 'c', 4, 5.6, 6.7]
resultado_contador = contar_inteiros(obj=obj)
print(resultado_contador)
# Out:
# Quantidade de inteiros: 4
# 4
