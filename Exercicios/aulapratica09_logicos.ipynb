# %%
1 == 1 and 1 == 1
# Out:
# True

# %%
1 == 1 and 1 == 2
# Out:
# False

# %%
1 != 0 and 1 == 1
# Out:
# True

# %%
1 != 0 or 1 == 1
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False and True and False
# Out:
# False

# %%
False or True and True
# Out:
# True

# %%
True and not True and True
# Out:
# False

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or False or True
# Out:
# True

# %%
p = 1
q = 0
r = 0

p == q == r and  p == 1
# Out:
# False

# %%
#visualizar um conjunto de dados grandes
1 in [1, 2, 2]
# Out:
# True

# %%
"1" in [1, 2, 2]
# Out:
# False
