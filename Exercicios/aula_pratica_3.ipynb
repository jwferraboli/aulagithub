# %%
tupla = (1, 2, 3, 4, 5)
tupla
# Out:
# (1, 2, 3, 4, 5)

# %%
type(tupla)
# Out:
# tuple

# %%
lista = [1, 2, 3, 4]

# %%
type(lista)
# Out:
# list

# %%
dicionario = {"a": 1, "b": 2, "c":3}
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
print(tupla)
tupla[1]
# Out:
# (1, 2, 3, 4, 5)
# 2

# %%
dicionario["c"]
# Out:
# 3

# %%
print(type(lista[3]))
print (lista[3])
# Out:
# <class 'int'>
# 4

# %%
lista[-4:]
# Out:
# [1, 2, 3, 4]

# %%
coxinha = ('q', 'w', 'e')

# %%
display(coxinha)
# Out:
# ('q', 'w', 'e')

# %%
tupla [-1] = 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tupla [-1] = 42
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista.append('42')

# %%
lista
# Out:
# [1, 2, 3, 4, '6', '42']

# %%
lista
# Out:
# [1, 2, 3, 4, '6', '42']

# %%
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dicionario [1] = "Abacate"
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 1: 'Abacate'}

# %%
lista.pop()
# Out:
# '42'

# %%
dicionario.pop
# Out:
# <function dict.pop>

# %%
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 1: 'Abacate'}

# %%
num = lista.pop()
print(f'{num} - {lista}')
# Out:
# 6 - [1, 2, 3, 4]

# %%
lista = [1, 2, 3, 4, 5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
novo_objeto = lista [3]
novo_objeto
# Out:
# 4

# %%
novo_objeto_xuxu = lista[0]
novo_objeto_amarelo = lista[1]
novo_objeto_verde = lista[3]
print (novo_objeto_xuxu, novo_objeto_amarelo, novo_objeto_verde)
# Out:
# 1 2 4

# %%
a, *b, d, e  = lista
print (a, b, c, d, e)
# Out:
# 1 [2, 3] 3 4 5

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 sum()
#
# TypeError: sum() takes at least 1 positional argument (0 given)
