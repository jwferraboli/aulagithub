# %%
num_1 = 4
num_2 = 2
print(num_1 + num_2)
# Out:
# 6

# %%
tupla_1 = (1, 2, 3)
tupla_2 = (1, 20, 3)
print(tupla_1 + tupla_2)
# Out:
# (1, 2, 3, 1, 20, 3)

# %%
tupla_1 += tupla_2
(tupla_1)
# Out:
# (1, 2, 3, 1, 20, 3)

# %%
tupla_1 = tupla_1 += tupla_2
diplay(tupla_1)
display(tupla_2)
# Out:
#   Cell In[7], line 1
#     tupla_1 = tupla_1 += tupla_2
#                       ^
# SyntaxError: invalid syntax

# %%
display (list(tupla_1))
display (tupla_1)
# Out:
# [1, 2, 3, 1, 20, 3, 1, 20, 3]
# (1, 2, 3, 1, 20, 3, 1, 20, 3)

# %%
dict_1.update(dict_2)
dict_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dict_1.update(dict_2)
#       2 dict_1
#
# NameError: name 'dict_1' is not defined

# %%
lista_da_tupla_1 = list (tupla_1)
lista_da_tupla_1
# Out:
# [1, 2, 3, 1, 20, 3, 1, 20, 3]

# %%
lista_da_tupla 1[2] += 2
lista_da_tupla_1
# Out:
#   Cell In[15], line 1
#     lista_da_tupla 1[2] += 2
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np

# %%
array = np.array(lista_da_tupla_1)
array
# Out:
# array([ 1,  2,  3,  1, 20,  3,  1, 20,  3])

# %%
array += 2
array
# Out:
# array([  3,   6,  11,   3, 402,  11,   3, 402,  11])

# %%
array *= array
array
# Out:
# array([  1,   4,   9,   1, 400,   9,   1, 400,   9])

# %%
np.insert(arr=array, obj=2, values=100)
# Out:
# array([  1,   4, 100,   9,   1, 400,   9,   1, 400,   9])

# %%
len(np.insert(arr=array, obj=2, values=100))
# Out:
# 10

# %%
np.insert(arr=np.array(['a''b']), obj=2, values=(0,1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 np.insert(arr=np.array(['a''b']), obj=2, values=(0,1))
#
# File c:\Users\julia\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\_function_base_impl.py:5589, in insert(arr, obj, values, axis)
#    5587 index = indices.item()
#    5588 if index < -N or index > N:
# -> 5589     raise IndexError(f"index {obj} is out of bounds for axis {axis} "
#    5590                      f"with size {N}")
#    5591 if (index < 0):
#    5592     index += N
#
# IndexError: index 2 is out of bounds for axis 0 with size 1

# %%
array = np.array(lista_da_tupla_1)
array.shape
# Out:
# (9,)

# %%
array = np.array(lista_da_tupla_1).reshape(3, 3)
array.shape
# Out:
# (3, 3)

# %%
import pandas as pd

# %%
df = pd.DataFrame(array)
df
# Out:
#    0   1  2
# 0  1   2  3
# 1  1  20  3
# 2  1  20  3

# %%
df += 2
df
# Out:
#    0   1  2
# 0  5   6  7
# 1  5  24  7
# 2  5  24  7

# %%
df += df
df
# Out:
#     0   1   2
# 0  10  12  14
# 1  10  48  14
# 2  10  48  14

# %%
##array_ones = np.ones_like(df)
array_ones = np.zeros_like(df)
array_ones[1,1] = 100
array_ones
# Out:
# array([[  0,   0,   0],
#        [  0, 100,   0],
#        [  0,   0,   0]])

# %%
df += array_ones
df
# Out:
#     0    1   2
# 0  11   13  15
# 1  11  248  15
# 2  11   49  15
